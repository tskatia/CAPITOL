# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if [ -f requirements.txt ]; then
#     pip install -r ./requirements.txt
# else
#     echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: seaborn in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 1)) (0.13.2)
# Requirement already satisfied: plotly in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 2)) (6.0.1)
# Requirement already satisfied: nltk in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 3)) (3.7)
# Requirement already satisfied: tensorflow in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 4)) (2.15.1)
# Requirement already satisfied: scikit-learn in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 5)) (1.1.3)
# Collecting xgboost
#   Downloading xgboost-3.0.2-py3-none-manylinux_2_28_x86_64.whl (253.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━ 253.9/253.9 MB 3.3 MB/s eta 0:00:00
# Collecting wordninja
#   Downloading wordninja-2.0.0.tar.gz (541 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 541.6/541.6 kB 57.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting datasets
#   Downloading datasets-4.0.0-py3-none-any.whl (494 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 494.8/494.8 kB 44.2 MB/s eta 0:00:00
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 590.6/590.6 kB 57.7 MB/s eta 0:00:00
# Collecting wordcloud
#   Downloading wordcloud-1.9.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 511.1/511.1 kB 51.0 MB/s eta 0:00:00
# Collecting gensim==4.3.3
#   Downloading gensim-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 26.5/26.5 MB 70.8 MB/s eta 0:00:00
# Collecting fasttext
#   Downloading fasttext-0.9.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 73.4/73.4 kB 7.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /root/venv/lib/python3.10/site-packages (from gensim==4.3.3->-r ./requirements.txt (line 11)) (1.9.3)
# Requirement already satisfied: smart-open>=1.8.1 in /root/venv/lib/python3.10/site-packages (from gensim==4.3.3->-r ./requirements.txt (line 11)) (6.4.0)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /root/venv/lib/python3.10/site-packages (from gensim==4.3.3->-r ./requirements.txt (line 11)) (1.25.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /root/venv/lib/python3.10/site-packages (from seaborn->-r ./requirements.txt (line 1)) (3.6.3)
# Requirement already satisfied: pandas>=1.2 in /root/venv/lib/python3.10/site-packages (from seaborn->-r ./requirements.txt (line 1)) (2.1.4)
# Requirement already satisfied: packaging in /root/venv/lib/python3.10/site-packages (from plotly->-r ./requirements.txt (line 2)) (25.0)
# Requirement already satisfied: narwhals>=1.15.1 in /root/venv/lib/python3.10/site-packages (from plotly->-r ./requirements.txt (line 2)) (1.38.0)
# Requirement already satisfied: tqdm in /root/venv/lib/python3.10/site-packages (from nltk->-r ./requirements.txt (line 3)) (4.67.1)
# Requirement already satisfied: regex>=2021.8.3 in /root/venv/lib/python3.10/site-packages (from nltk->-r ./requirements.txt (line 3)) (2024.11.6)
# Requirement already satisfied: joblib in /root/venv/lib/python3.10/site-packages (from nltk->-r ./requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: click in /root/venv/lib/python3.10/site-packages (from nltk->-r ./requirements.txt (line 3)) (8.1.8)
# Requirement already satisfied: google-pasta>=0.1.1 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (4.13.2)
# Requirement already satisfied: absl-py>=1.0.0 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (2.15.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (2.15.2)
# Requirement already satisfied: h5py>=2.9.0 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (18.1.1)
# Requirement already satisfied: astunparse>=1.6.0 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (0.3.2)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (0.6.0)
# Requirement already satisfied: six>=1.12.0 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (2.15.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (25.2.10)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (0.37.1)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (65.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (4.25.7)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /root/venv/lib/python3.10/site-packages (from tensorflow->-r ./requirements.txt (line 4)) (1.71.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /root/venv/lib/python3.10/site-packages (from scikit-learn->-r ./requirements.txt (line 5)) (3.6.0)
# Collecting nvidia-nccl-cu12
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━ 322.3/322.3 MB 2.1 MB/s eta 0:00:00
# Collecting multiprocess<0.70.17
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 134.8/134.8 kB 22.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /root/venv/lib/python3.10/site-packages (from datasets->-r ./requirements.txt (line 8)) (3.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /root/venv/lib/python3.10/site-packages (from datasets->-r ./requirements.txt (line 8)) (6.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from datasets->-r ./requirements.txt (line 8)) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from datasets->-r ./requirements.txt (line 8)) (0.3.8)
# Requirement already satisfied: fsspec[http]<=2025.3.0,>=2023.1.0 in /toolkit-cache/0.2.26/python3.10/kernel-libs/lib/python3.10/site-packages (from datasets->-r ./requirements.txt (line 8)) (2024.6.1)
# Collecting xxhash
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 194.1/194.1 kB 27.4 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.24.0
#   Downloading huggingface_hub-0.33.4-py3-none-any.whl (515 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 515.3/515.3 kB 66.3 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.32.2 in /root/venv/lib/python3.10/site-packages (from datasets->-r ./requirements.txt (line 8)) (2.32.3)
# Requirement already satisfied: pillow in /root/venv/lib/python3.10/site-packages (from wordcloud->-r ./requirements.txt (line 10)) (11.2.1)
# Collecting pybind11>=2.2
#   Using cached pybind11-3.0.0-py3-none-any.whl (292 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow->-r ./requirements.txt (line 4)) (0.45.1)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.12.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 1.6/1.6 MB 92.3 MB/s eta 0:00:00
# Collecting hf-xet<2.0.0,>=1.1.2
#   Downloading hf_xet-1.1.5-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 3.1/3.1 MB 123.4 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ./requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ./requirements.txt (line 1)) (1.4.8)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ./requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ./requirements.txt (line 1)) (4.57.0)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ./requirements.txt (line 1)) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/venv/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->-r ./requirements.txt (line 1)) (3.2.3)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn->-r ./requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.10/site-packages (from pandas>=1.2->seaborn->-r ./requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets->-r ./requirements.txt (line 8)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets->-r ./requirements.txt (line 8)) (2025.4.26)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets->-r ./requirements.txt (line 8)) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets->-r ./requirements.txt (line 8)) (2.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /root/venv/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (3.8)
# Requirement already satisfied: werkzeug>=1.0.1 in /root/venv/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (3.1.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /root/venv/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (2.40.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /root/venv/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (0.7.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /root/venv/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (1.2.2)
# Collecting aiosignal>=1.4.0
#   Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting async-timeout<6.0,>=4.0
#   Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.6.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 241.6/241.6 kB 31.6 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (326 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 326.1/326.1 kB 87.3 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.7.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 222.9/222.9 kB 45.7 MB/s eta 0:00:00
# Collecting propcache>=0.2.0
#   Downloading propcache-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━ 198.3/198.3 kB 57.2 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /root/venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r ./requirements.txt (line 8)) (25.3.0)
# Collecting aiohappyeyeballs>=2.5.0
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in /root/venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (4.9.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /root/venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /root/venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /root/venv/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /root/venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /root/venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /root/venv/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow->-r ./requirements.txt (line 4)) (3.2.2)
# Building wheels for collected packages: wordninja, fasttext
#   Building wheel for wordninja (setup.py): started
#   Building wheel for wordninja (setup.py): finished with status 'done'
#   Created wheel for wordninja: filename=wordninja-2.0.0-py3-none-any.whl size=541530 sha256=396ed3695275d7d2389d1d90e0924ca6432f1b1ccb1050c3d1561626b3d8ce31
#   Stored in directory: /root/.cache/pip/wheels/aa/44/3a/f2a5c1859b8b541ded969b4cd12d0a58897f12408f4f51e084
#   Building wheel for fasttext (pyproject.toml): started
#   Building wheel for fasttext (pyproject.toml): finished with status 'done'
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp310-cp310-linux_x86_64.whl size=4978561 sha256=fcffab961e6a8bca9c19265b9ea0a360eed2622e146c5bb67d761d887aa74122
#   Stored in directory: /root/.cache/pip/wheels/0d/a2/00/81db54d3e6a8199b829d58e02cec2ddb20ce3e59fad8d3c92a
# Successfully built wordninja fasttext
# Installing collected packages: wordninja, xxhash, pybind11, propcache, nvidia-nccl-cu12, multiprocess, multidict, hf-xet, frozenlist, emoji, async-timeout, aiohappyeyeballs, yarl, xgboost, huggingface-hub, gensim, fasttext, aiosignal, wordcloud, aiohttp, datasets
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.14 aiosignal-1.4.0 async-timeout-5.0.1 datasets-4.0.0 emoji-2.14.1 fasttext-0.9.3 frozenlist-1.7.0 gensim-4.3.3 hf-xet-1.1.5 huggingface-hub-0.33.4 multidict-6.6.3 multiprocess-0.70.16 nvidia-nccl-cu12-2.27.5 propcache-0.3.2 pybind11-3.0.0 wordcloud-1.9.4 wordninja-2.0.0 xgboost-3.0.2 xxhash-3.5.0 yarl-1.20.1
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
